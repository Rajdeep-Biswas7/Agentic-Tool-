# %% [markdown]
# messages

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")

model=init_chat_model("google_genai:gemini-2.5-flash-lite")
response = model.invoke("What is the capital of France?")
print(response.content)
# Out:
# The capital of France is **Paris**.

# %%
model.invoke("what is ai?")
# Out:
# AIMessage(content='AI, or **Artificial Intelligence**, is a broad field of computer science focused on creating systems that can perform tasks that typically require human intelligence.\n\nThink of it as building machines that can **think, learn, and act** in ways that mimic human cognitive abilities.\n\nHere\'s a breakdown of what that means and some key aspects of AI:\n\n**Core Concepts:**\n\n*   **Learning:** AI systems can learn from data, identify patterns, and improve their performance over time without being explicitly programmed for every single scenario. This is often achieved through techniques like **machine learning**.\n*   **Reasoning and Problem Solving:** AI can analyze information, draw conclusions, and develop strategies to solve problems, much like humans do.\n*   **Perception:** AI can interpret sensory input, such as images (computer vision) or sounds (speech recognition), to understand its environment.\n*   **Decision Making:** Based on its learning and reasoning, AI can make decisions, often in complex situations.\n*   **Natural Language Processing (NLP):** This allows AI to understand, interpret, and generate human language, enabling tasks like translation, chatbots, and sentiment analysis.\n\n**Key Subfields and Technologies:**\n\n*   **Machine Learning (ML):** A subset of AI where algorithms learn from data to make predictions or decisions.\n    *   **Supervised Learning:** Learning from labeled data (e.g., identifying cats in pictures based on labeled cat images).\n    *   **Unsupervised Learning:** Finding patterns in unlabeled data (e.g., clustering customers into different groups).\n    *   **Reinforcement Learning:** Learning through trial and error, receiving rewards or penalties for actions (e.g., training a robot to walk).\n*   **Deep Learning (DL):** A subfield of ML that uses artificial neural networks with multiple layers (hence "deep") to learn complex patterns from vast amounts of data. This is behind many recent AI breakthroughs.\n*   **Natural Language Processing (NLP):** As mentioned above, enabling machines to understand and interact with human language.\n*   **Computer Vision:** Allowing machines to "see" and interpret images and videos.\n*   **Robotics:** Integrating AI with physical robots to enable them to perform tasks in the real world.\n*   **Expert Systems:** AI systems designed to mimic the decision-making ability of a human expert in a specific domain.\n\n**What AI is NOT (yet):**\n\nIt\'s important to distinguish between the current state of AI and the fictional portrayals of AI.\n\n*   **Consciousness or Sentience:** Current AI systems do not possess consciousness, emotions, or self-awareness in the way humans do. They are sophisticated algorithms.\n*   **General Intelligence (AGI):** While AI excels at specific tasks (Narrow AI), it hasn\'t yet reached Artificial General Intelligence (AGI), which would be AI capable of understanding, learning, and applying intelligence to any intellectual task that a human being can.\n\n**Applications of AI:**\n\nAI is already integrated into many aspects of our lives:\n\n*   **Virtual Assistants:** Siri, Alexa, Google Assistant\n*   **Recommendation Engines:** Netflix, Amazon, Spotify\n*   **Self-Driving Cars:** Autonomous vehicle technology\n*   **Medical Diagnosis:** Analyzing medical images, predicting disease risk\n*   **Fraud Detection:** Identifying suspicious financial transactions\n*   **Customer Service:** Chatbots and automated support\n*   **Content Creation:** Generating text, images, and music\n*   **Gaming:** Intelligent Non-Player Characters (NPCs)\n\n**In Summary:**\n\nAI is about building intelligent machines that can learn, reason, and perform tasks that traditionally require human intellect. It\'s a rapidly evolving field with the potential to transform many industries and aspects of our lives.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [] ...

# %% [markdown]
# text prompt

# %%
model.invoke("what is langchain?")
# Out:
# AIMessage(content='Langchain is an **open-source framework designed to help developers build applications powered by large language models (LLMs)**. In simpler terms, it\'s a toolkit that makes it much easier to connect LLMs to other data sources and to enable them to perform more complex tasks than just generating text.\n\nThink of it like this:\n\n*   **LLMs are powerful engines for understanding and generating text.** They can answer questions, write stories, translate languages, and more.\n*   **Langchain is the chassis, the steering wheel, the transmission, and the various other parts that allow you to build a functional vehicle (an LLM-powered application) around that engine.** It provides the structure and tools to make the LLM useful in real-world scenarios.\n\nHere are the core concepts and what makes Langchain so valuable:\n\n**Key Concepts and Components:**\n\n*   **LLMs:** Langchain integrates with various LLMs (like OpenAI\'s GPT models, Hugging Face models, etc.), allowing you to easily swap them out.\n*   **Prompts:** This is how you communicate with LLMs. Langchain offers tools to manage and format prompts effectively, making them more dynamic and reusable.\n*   **Chains:** This is a fundamental concept. Chains allow you to combine multiple LLM calls or other components in a sequence to achieve a more complex outcome. For example, you might have a chain that first retrieves information from a document, then uses that information to answer a question.\n*   **Agents:** Agents are a more advanced form of chains. They use LLMs to **reason** about which actions to take. They can decide to use tools (like searching the web, accessing a database, or running code) to gather information or perform tasks, and then use that information to generate a final output.\n*   **Memory:** LLMs are stateless by default. Memory allows your application to "remember" previous interactions, enabling conversational capabilities and context-aware responses.\n*   **Indexes:** Langchain provides tools for structuring and querying external data. This is crucial for LLMs to access and utilize information beyond their training data. Common examples include:\n    *   **Document Loaders:** For ingesting data from various sources (PDFs, websites, databases, etc.).\n    *   **Text Splitters:** For breaking down large documents into smaller, manageable chunks.\n    *   **Vector Stores:** For storing and retrieving text embeddings, which are numerical representations of text that allow for semantic search.\n*   **Tools:** These are external functionalities that agents can leverage. Examples include:\n    *   Search engines (Google, Bing)\n    *   Databases\n    *   APIs\n    *   Code interpreters\n\n**Why is Langchain important?**\n\n*   **Simplifies LLM integration:** It abstracts away much of the complexity of interacting with LLMs, allowing developers to focus on application logic.\n*   **Enables complex workflows:** By chaining components together, you can build sophisticated LLM applications that go beyond simple text generation.\n*   **Facilitates data integration:** Langchain makes it easy to connect LLMs to your own data, making them more relevant and powerful for your specific use cases.\n*   **Promotes modularity and reusability:** The framework encourages building applications in a modular way, making components reusable across different projects.\n*   **Rapid prototyping:** It speeds up the development and experimentation process for LLM-powered applications.\n\n**Common Use Cases for Langchain:**\n\n*   **Chatbots and Conversational AI:** Building sophisticated chatbots that can maintain context and access external information.\n*   **Question Answering Systems:** Creating systems that can answer questions based on a large corpus of documents.\n*   **Data Analysis and Summarization:** Using LLMs to extract insights and summarize information from various data sources.\n*   **Content Generation:** Automating the creation of articles, mar ...

# %% [markdown]
# message prompt

# %% [markdown]
# system message

# %%
from langchain.messages import SystemMessage, HumanMessage, AIMessage
messages = [
        SystemMessage(content="You are a helpful assistant."),
        HumanMessage(content="What is the capital of France?"),
        AIMessage(content="The capital of France is Paris.")
 ]
response=model.invoke(messages)
response.content
# Out:
# ''

# %%
system_msg = SystemMessage(content="You are a helpful assistant.")

messages = [
    system_msg,
    HumanMessage(content="What is the capital of France?"),
    AIMessage(content="The capital of France is Paris.")
]
response = model.invoke(messages)
print(response.content)
