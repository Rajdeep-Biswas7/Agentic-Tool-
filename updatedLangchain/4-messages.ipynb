# %% [markdown]
# messages

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")

model=init_chat_model("google_genai:gemini-2.5-flash-lite")
response = model.invoke("What is the capital of France?")
print(response.content)
# Out:
# The capital of France is **Paris**.

# %%
model.invoke("what is ai?")
# Out:
# AIMessage(content="AI stands for **Artificial Intelligence**.\n\nIn its simplest form, AI refers to the **simulation of human intelligence in machines that are programmed to think and learn like humans.**\n\nHowever, the definition of AI is much broader and encompasses a wide range of capabilities and approaches. Here's a breakdown of what AI generally means:\n\n**Key Concepts of AI:**\n\n*   **Learning:** AI systems can learn from data without being explicitly programmed for every scenario. This learning can happen in various ways, such as:\n    *   **Machine Learning (ML):** A subset of AI where algorithms learn from data to make predictions or decisions.\n    *   **Deep Learning (DL):** A further subset of ML that uses artificial neural networks with multiple layers to learn complex patterns from vast amounts of data.\n*   **Problem-Solving:** AI can be used to solve complex problems that would typically require human intellect, such as finding the optimal solution to a logistical challenge or diagnosing a disease.\n*   **Perception:** AI systems can interpret sensory input, such as images (computer vision), audio (speech recognition), and text (natural language processing).\n*   **Reasoning:** AI can draw inferences and make logical deductions based on available information.\n*   **Decision-Making:** AI can make choices and take actions based on its learning, reasoning, and perception.\n*   **Adaptation:** AI systems can adapt their behavior and performance over time as they encounter new data or situations.\n\n**What AI is NOT (or not yet):**\n\nIt's important to distinguish between current AI and hypothetical future AI:\n\n*   **Consciousness/Sentience:** Current AI does not possess consciousness, self-awareness, or emotions in the way humans do.\n*   **General Human-Level Intelligence (AGI):** While AI is rapidly advancing, we haven't yet achieved Artificial General Intelligence (AGI), which would be an AI with the ability to understand, learn, and apply knowledge across a wide range of tasks at a human level. Most current AI is **Narrow AI** or **Weak AI**, designed for specific tasks.\n\n**Examples of AI in Action:**\n\nYou encounter AI in many aspects of your daily life:\n\n*   **Virtual Assistants:** Siri, Alexa, Google Assistant\n*   **Recommendation Systems:** Netflix suggesting movies, Amazon recommending products\n*   **Image Recognition:** Tagging photos on social media, facial recognition in security systems\n*   **Natural Language Processing:** Translation tools, chatbots, spam filters\n*   **Autonomous Vehicles:** Self-driving cars\n*   **Healthcare:** Diagnosing diseases, drug discovery\n*   **Finance:** Fraud detection, algorithmic trading\n*   **Gaming:** Non-player characters (NPCs) in video games\n\n**The Goal of AI:**\n\nThe ultimate goal of AI research is to create intelligent machines that can assist humans, automate tasks, solve complex problems, and potentially even augment human capabilities.\n\nIn summary, AI is a broad and evolving field focused on creating machines that can perform tasks that typically require human intelligence. It's a powerful technology with the potential to transform many aspects of our lives.", additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019e68f8-e737-7992-b502-8cb3e0ff547a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 5, 'output_tokens': 651, 'total_tokens': 656, 'input_token_details': {'cache_read': 0}})

# %% [markdown]
# text prompt

# %%
model.invoke("what is langchain?")
# Out:
# AIMessage(content='LangChain is a **framework for developing applications powered by large language models (LLMs)**. It aims to simplify the process of building complex LLM applications by providing a modular and extensible set of tools and abstractions.\n\nThink of it as a **toolkit that helps you connect LLMs to other data sources and computational tools**, enabling you to create more sophisticated and powerful applications than you could by simply interacting with an LLM directly.\n\nHere\'s a breakdown of what that means and why it\'s important:\n\n**The Core Problem LangChain Solves:**\n\nLLMs are incredibly powerful at understanding and generating text, but they are inherently stateless and don\'t have direct access to external information or the ability to perform actions in the real world. To build truly useful applications, you need to:\n\n*   **Integrate LLMs with data:** Access databases, APIs, documents, websites, etc., to provide context to the LLM.\n*   **Enable LLMs to act:** Allow LLMs to call external tools like search engines, calculators, or even code interpreters.\n*   **Manage complex workflows:** Orchestrate multiple LLM calls and tool executions in a specific order.\n*   **Maintain state and memory:** Allow LLMs to remember past interactions within a conversation.\n\n**Key Concepts and Components of LangChain:**\n\nLangChain is built around several core components that work together:\n\n1.  **Models:**\n    *   **LLMs:** Interfaces to various LLM providers (OpenAI, Hugging Face, Cohere, etc.).\n    *   **Chat Models:** Specifically designed for conversational AI, handling message history.\n    *   **Text Embedding Models:** Convert text into numerical vectors for semantic search and comparison.\n\n2.  **Prompts:**\n    *   **Prompt Templates:** Reusable structures for generating prompts, allowing you to inject variables and dynamically create prompts.\n    *   **Output Parsers:** Tools to structure the LLM\'s output into a desired format (e.g., JSON, lists).\n\n3.  **Chains:**\n    *   **The core of LangChain.** Chains allow you to combine multiple LLM calls and other components into a sequential workflow.\n    *   **Simple Sequential Chains:** Execute components one after another.\n    *   **LLMChain:** A basic chain that combines a prompt template with an LLM.\n    *   **More complex chains:** Can involve multiple LLMs, tools, and logic.\n\n4.  **Indexes:**\n    *   **Document Loaders:** Tools to load data from various sources (files, websites, databases).\n    *   **Text Splitters:** Break down large documents into smaller chunks for better LLM processing.\n    *   **Vector Stores:** Store document embeddings and enable efficient similarity search.\n    *   **Retrievers:** Abstract away the complexity of fetching relevant documents from a vector store or other data sources.\n\n5.  **Agents:**\n    *   **The most advanced concept.** Agents use LLMs to decide which actions to take and in what order. They have access to a set of "tools" (e.g., search engines, calculators, APIs) and use the LLM to reason about which tool to use and how to use it to achieve a given goal.\n    *   **Tools:** Functions or APIs that an agent can call.\n\n6.  **Memory:**\n    *   **Conversation Buffer Memory:** Stores previous messages in a conversation.\n    *   **Summary Memory:** Summarizes past conversations to save context.\n    *   Other memory types to manage conversational state.\n\n**Why Use LangChain?**\n\n*   **Abstraction and Modularity:** LangChain provides clean interfaces and reusable components, making your code more organized and easier to maintain.\n*   **Interoperability:** It supports a wide range of LLMs, data sources, and tools, allowing you to mix and match components.\n*   **Rapid Prototyping:** Quickly build and experiment with LLM-powered applications.\n*   **Complexity Management:** Handles the complexities of orchestrating LLM calls, managing prompts, and integrating external data.\n*   **Extensibil ...

# %% [markdown]
# message prompt

# %% [markdown]
# system message

# %%
from langchain.messages import SystemMessage, HumanMessage, AIMessage
messages = [
        SystemMessage(content="You are a helpful assistant."),
        HumanMessage(content="What is the capital of France?"),
        AIMessage(content="The capital of France is Paris.")
 ]
response=model.invoke(messages)
response.content

# %%
system_msg = SystemMessage(content="You are a helpful assistant.")

messages = [
    system_msg,
    HumanMessage(content="What is the capital of France?"),
    AIMessage(content="The capital of France is Paris.")
]
response = model.invoke(messages)
print(response.content)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File c:\Users\rb877\OneDrive\Desktop\langchain\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:3166, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3165 try:
# -> 3166     response: GenerateContentResponse = self.client.models.generate_content(
#    3167         **request,
#    3168     )
#    3169 except ClientError as e:
#
# File c:\Users\rb877\OneDrive\Desktop\langchain\.venv\Lib\site-packages\google\genai\models.py:6331, in Models.generate_content(self, model, contents, config)
#    6330 i += 1
# -> 6331 response = self._generate_content(
#    6332     model=model, contents=contents, config=parsed_config
#    6333 )
#    6335 function_map = _extra_utils.get_function_map(parsed_config)
#
# File c:\Users\rb877\OneDrive\Desktop\langchain\.venv\Lib\site-packages\google\genai\models.py:4767, in Models._generate_content(self, model, contents, config)
#    4765 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4767 response = self._api_client.request(
#    4768     'post', path, request_dict, http_options
#    4769 )
#    4771 if config is not None and getattr(
#    4772     config, 'should_return_http_response', None
#    4773 ):
#
# File c:\Users\rb877\OneDrive\Desktop\langchain\.venv\Lib\site-packages\google\genai\_api_client.py:1605, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1602 http_request = self._build_request(
#    1603     http_method, path, request_dict, http_options
#    1604 )
# -> 1605 response = self._request(http_request, http_options, stream=False)
#    1606 response_body = (
#    1607     response.response_stream[0] if response.response_stream else ''
#    1608 )
#
# File c:\Users\rb877\OneDrive\Desktop\langchain\.venv\Lib\site-packages\google\genai\_api_client.py:1396, in BaseApiClient._request(self, http_request, http_options, stream)
#    1395     retry = tenacity.Retrying(**retry_kwargs)
# -> 1396     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
#    1398 return self._retry(self._request_once, http_request, stream)
#
# File c:\Users\rb877\OneDrive\Desktop\langchain\.venv\Lib\site-packages\tenacity\__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     469 while True:
# --> 470     do = self.iter(retry_state=retry_state)
#     471     if isinstance(do, DoAttempt):
#
# File c:\Users\rb877\OneDrive\Desktop\langchain\.venv\Lib\site-packages\tenacity\__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File c:\Users\rb877\OneDrive\Desktop\langchain\.venv\Lib\site-packages\tenacity\__init__.py:413, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     412 if self.reraise:
# --> 413     raise retry_exc.reraise()
#     414 raise retry_exc from fut.exception()
#
# File c:\Users\rb877\OneDrive\Desktop\langchain\.venv\Lib\site-packages\tenacity\__init__.py:184, in RetryError.reraise(self)
#     183 if self.last_attempt.failed:
# --> 184     raise self.last_attempt.result()
#     185 raise self
#
# File C:\Python314\Lib\concurrent\futures\_base.py:443, in Future.result(self, timeout)
#     442 elif self._state == FINISHED:
# --> 443     return self.__get_result()
#     445 self._condition.wait(timeout)
#
# File C:\Python314\Lib\concurrent\futures\_base.py:395, in Future.__get_result(self)
#     394 try:
# --> 395     raise self._exception
#     396 finally:
#     397     # Break a reference cycle with the exception in self._exception
#
# File c:\Users\rb877\OneDrive\Desktop\langchain\.venv\Lib\site-packages\tenacity\__init__.py:473, in Retrying.__call__(self, fn, *args, **kwargs)
#     472 try:
# --> 473     result = fn(*args, **kwargs)
#     474 except BaseException:  # noqa: B902
#
# File c:\Users\rb877\OneDrive\Desktop\langchain\.venv\Lib\site-packages\google\genai\_api_client.py:1375, in BaseApiClient._request_once(self, http_request, stream)
#    1374   response = self._httpx_client.send(httpx_request, stream=stream)  # type: ignore[union-attr]
# -> 1375 errors.APIError.raise_for_response(response)
#    1376 return HttpResponse(
#    1377     response.headers, response if stream else [response.text]
#    1378 )
#
# File c:\Users\rb877\OneDrive\Desktop\langchain\.venv\Lib\site-packages\google\genai\errors.py:155, in APIError.raise_for_response(cls, response)
#     153   response_json = response.body_segments[0].get('error', {})
# --> 155 cls.raise_error(response.status_code, response_json, response)
#
# File c:\Users\rb877\OneDrive\Desktop\langchain\.venv\Lib\site-packages\google\genai\errors.py:184, in APIError.raise_error(cls, status_code, response_json, response)
#     183 if 400 <= status_code < 500:
# --> 184   raise ClientError(status_code, response_json, response)
#     185 elif 500 <= status_code < 600:
#
# ClientError: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash-lite\nPlease retry in 10.576111508s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '10s'}]}}
#
# The above exception was the direct cause of the following exception:
#
# ChatGoogleGenerativeAIError               Traceback (most recent call last)
# Cell In[22], line 8
#       4     system_msg,
#       5     HumanMessage(content="What is the capital of France?"),
#       6     AIMessage(content="The capital of France is Paris.")
#       7 ]
# ----> 8 response = model.invoke(messages)
#       9 print(response.content)
#
# File c:\Users\rb877\OneDrive\Desktop\langchain\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:2644, in ChatGoogleGenerativeAI.invoke(self, input, config, code_execution, stop, **kwargs)
#    2641         msg = "Tools are already defined.code_execution tool can't be defined"
#    2642         raise ValueError(msg)
# -> 2644 return super().invoke(input, config, stop=stop, **kwargs)
#
# File c:\Users\rb877\OneDrive\Desktop\langchain\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:474, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     460 @override
#     461 def invoke(
#     462     self,
#    (...)    467     **kwargs: Any,
#     468 ) -> AIMessage:
#     469     config = ensure_config(config)
#     470     return cast(
#     471         "AIMessage",
#     472         cast(
#     473             "ChatGeneration",
# --> 474             self.generate_prompt(
#     475                 [self._convert_input(input)],
#     476                 stop=stop,
#     477                 callbacks=config.get("callbacks"),
#     478                 tags=config.get("tags"),
#     479                 metadata=config.get("metadata"),
#     480                 run_name=config.get("run_name"),
#     481                 run_id=config.pop("run_id", None),
#     482                 **kwargs,
#     483             ).generations[0][0],
#     484         ).message,
#     485     )
#
# File c:\Users\rb877\OneDrive\Desktop\langchain\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1823, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1814 @override
#    1815 def generate_prompt(
#    1816     self,
#    (...)   1820     **kwargs: Any,
#    1821 ) -> LLMResult:
#    1822     prompt_messages = [p.to_messages() for p in prompts]
# -> 1823     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\rb877\OneDrive\Desktop\langchain\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1630, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1627 for i, m in enumerate(input_messages):
#    1628     try:
#    1629         results.append(
# -> 1630             self._generate_with_cache(
#    1631                 m,
#    1632                 stop=stop,
#    1633                 run_manager=run_managers[i] if run_managers else None,
#    1634                 **kwargs,
#    1635             )
#    1636         )
#    1637     except BaseException as e:
#    1638         if run_managers:
#
# File c:\Users\rb877\OneDrive\Desktop\langchain\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1970, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1968     result = generate_from_stream(iter(chunks))
#    1969 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1970     result = self._generate(
#    1971         messages, stop=stop, run_manager=run_manager, **kwargs
#    1972     )
#    1973 else:
#    1974     result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\Users\rb877\OneDrive\Desktop\langchain\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:3170, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3166     response: GenerateContentResponse = self.client.models.generate_content(
#    3167         **request,
#    3168     )
#    3169 except ClientError as e:
# -> 3170     _handle_client_error(e, request)
#    3172 return _response_to_result(response)
#
# File c:\Users\rb877\OneDrive\Desktop\langchain\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:169, in _handle_client_error(e, request)
#     167 model_name = request.get("model", "unknown")
#     168 msg = f"Error calling model '{model_name}' ({e.status}): {e}"
# --> 169 raise ChatGoogleGenerativeAIError(msg) from e
#
# ChatGoogleGenerativeAIError: Error calling model 'gemini-2.5-flash-lite' (RESOURCE_EXHAUSTED): 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash-lite\nPlease retry in 10.576111508s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '10s'}]}}
