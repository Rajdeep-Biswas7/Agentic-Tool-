# %% [markdown]
# Models Integration With OpenAI, Google Gemini and GROQ

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GOOGLE_API_KEY"]=os.getenv("GOOGLE_API_KEY")

# %% [markdown]
# Google Gemini Model Integration

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GOOGLE_API_KEY"]=os.getenv("GOOGLE_API_KEY")
model=init_chat_model("google_genai:gemini-2.5-flash-lite")
response = model.invoke("What is the capital of France?")
print(response.content)
# Out:
# The capital of France is **Paris**.

# %%
import os
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")
response = model.invoke("What is the capital of america?")
print(response.content)
# Out:
# The capital of the United States of America is **Washington, D.C.**

# %% [markdown]
# Groq Model Integration

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")
model=init_chat_model("groq:llama-3.3-70b-versatile")
response = model.invoke("What is the capital of America?")
print(response.content)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       1 import os
#       2 from langchain.chat_models import init_chat_model
#       3
# ----> 4 os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")
#       5 model=init_chat_model("groq:llama-3.3-70b-versatile")
#       6 response = model.invoke("What is the capital of America?")
#       7 print(response.content)
#
# File <frozen os>:714, in _Environ.__setitem__(self, key, value)
#     712 'Could not get source, probably due dynamically evaluated source code.'
#
# File <frozen os>:774, in _create_environ_mapping.<locals>.check_str(value)
#     772 'Could not get source, probably due dynamically evaluated source code.'
#
# TypeError: str expected, not NoneType

# %%
model.invoke("write a haiku about the sea")
# Out:
# AIMessage(content="Crashing waves below\nSalty scent and seaweed dance\nOcean's soothing song", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 18, 'prompt_tokens': 42, 'total_tokens': 60, 'completion_time': 0.060977701, 'completion_tokens_details': None, 'prompt_time': 0.003934169, 'prompt_tokens_details': None, 'queue_time': 0.312917339, 'total_time': 0.06491187}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_0761e44d7b', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019e5fcb-35df-72f3-9697-7ab43a8d8952-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 42, 'output_tokens': 18, 'total_tokens': 60})

# %%
model.stream("write a haiku about the sea")
# Out:
# <generator object BaseChatModel.stream at 0x000001E229CCDB60>

# %%
for chunk in model.stream("why is the sky blue?"):
    print(chunk.text, end="|", flush = True)
# Out:
# The sky is blue because of| a phenomenon called **Rayleigh scattering**. Here's a breakdown of how it works:
#
# |1.  **Sunlight is a mixture of colors:** Sunlight, which appears white to us, is actually made up of all the colors of the rainbow. You can see this when light passes through a prism and separates into its constituent colors (red|, orange, yellow, green, blue, indigo, violet). Each color has a different wavelength.
#
# 2.  **Earth's atmosphere:** The Earth is surrounded by an atmosphere composed of gases like nitrogen (about 78%)| and oxygen (about 21%), along with smaller amounts of other gases and tiny particles.
#
# 3.  **Scattering of light:** When sunlight enters the Earth's atmosphere, it interacts with these gas molecules and particles. This interaction causes| the light to scatter, meaning it bounces off in all directions.
#
# ...

# %% [markdown]
# batch

# %%
responses=model.batch([
    "how i become smarter?",
    "how i become a good coder?"
])
for response in responses:
    print(response.content)
# Out:
# Becoming smarter is a lifelong journey, not a destination. It's about cultivating a curious mind, actively seeking knowledge, and developing effective ways to process and apply what you learn. Here's a comprehensive guide on how to become smarter:
#
# **I. Cultivate a Growth Mindset:**
#
# *   **Believe in your ability to learn:** Understand that intelligence isn't fixed. Your brain is capable of change and growth (neuroplasticity). Embrace challenges and see them as opportunities to learn.
# *   **Embrace effort:** Recognize that effort is crucial for learning and skill development. Don't shy away from hard work.
# *   **Learn from criticism:** View feedback as valuable information to improve, not as a personal attack.
# *   **Celebrate the success of others:** Be inspired by others' achievements, rather than feeling threatened.
#
# **II. Actively Seek and Absorb Knowledge:**
#
# *   **Read widely and deeply:**
# ...
